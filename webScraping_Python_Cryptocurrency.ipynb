# %% [markdown]
# # Web Scraping Cryptocurrency Data

# %% [markdown]
# ## import

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # HTTP Request
# ## store website

# %%
website='https://www.coingecko.com/'

# %% [markdown]
# ## get request

# %%
response= requests.get(website)

# %% [markdown]
# ## status code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## soup

# %%
soup= BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script src="/cdn-cgi/apps/head/gYtXOyllgyP3-Z2iKTP8rRWGBm4.js"></script><script async="" defer="" src="https://www.googleoptimize.com/optimize.js?id=GTM-W3CD992"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/OpensearchDescription.xml" rel="search" type="application/opensearchdescription+xml">
# <title>Cryptocurrency Prices, Charts, and Crypto Market Cap | CoinGecko</title>
# <meta content="View top cryptocurrency prices live, crypto charts, market cap, and trading volume. Discover today’s new and trending coins, top crypto gainers and losers in the market." name="description">
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-NP34MX7');</script>
# <link crossorigin="anonymous" href="https://static.coingecko.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://static.coingecko.com" rel="dns-prefetch"/>
# <link href="//www.googletagmanager.com" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://static.coingecko.com/webfonts/fa-solid-900.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://static.coingecko.com/webfonts/fa-brands-400.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://static.coingecko.com/webfonts/fa-regular-400.woff2" rel="preload" type="font/woff2"/>
# <link href="https://cdn4.buysellads.net" rel="preconnect"/>
# <meta content="Cryptocurrency Prices, Charts, and Crypto Market Cap | CoinGecko" property="og:title"/>
# <meta content="website" property="og:type">
# <meta content="View top cryptocurrency prices live, crypto charts, market cap, and trading volume. Discover today’s new and trending coins, top crypto gainers and losers in the market." property="og:description"/>
# <meta content="https://static.coingecko.com/s/thumbnail-d5a7c1de76b4bc1332e48227dc1d1582c2c92721b5552aae76664eecb68345c9.png" property="og:image"/>
# <meta content="https://www.coingecko.com/" property="og:url"/>
# <meta content="CoinGecko" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@coingecko" name="twitter:site"/>
# <meta content="@coingecko" name="twitter:creator"/>
# <meta content="Cryptocurrency Prices, Charts, and Crypto Market Cap | CoinGecko" name="twitter:title"/>
# <meta content="View top cryptocurrency prices live, crypto charts, market cap, and trading volume. Discover today’s new and trending coins, top crypto gainers and losers in the market." name="twitter:description"/>
# <meta content="https://static.coingecko.com/s/thumbnail-d5a7c1de76b4bc1332e48227dc1d1582c2c92721b5552aae76664eecb68345c9.png" name="twitter:image"/>
# <link href="https://www.coingecko.com/" rel="canonical">
# <link href="https://www.coingecko.com/" hreflang="en" rel="alternate">
# <link href="https://www.coingecko.com/zh" hreflang="zh" rel="alternate">
# <link href="https://www.coingecko.com/zh-tw" hreflang="zh-tw" rel="alternate">
# <link href="https://www.coingecko.com/de" hreflang="de" rel="alternate"/>
# <link href="https://www.coingecko.com/fr" hreflang="fr" rel="alternate"/>
# <link href="https://www.coingecko.com/es" hreflang="es" rel="alternate"/>
# <link href="https://www.coingecko.com/ja" hreflang="ja" rel="alternate"/>
# <link href="https://www.coingecko.com/id" hreflang="id" rel="alternate"/>
# <link href="https://www.coingecko.com/ru" hreflang="ru" rel="alternate"/>
# <link href="https://www.coingecko.com/ko" hreflang="ko" rel="alternate"/>
# <link href="https://www.coingecko.com/ar" hreflang="ar" rel="alternate"/>
# <link href="https://www.coingecko.com/th" hreflang="th" rel="alternate"/>
# <link href="https://www.coingecko.com/vi" hreflang="vi" rel="alternate"/>
# <link href="https://www.coingecko.com/it" hreflang="it" rel="alternate"/>
# <link href="https://www.coingecko.com/pt" hreflang="pt" rel="alternate"/>
# <link href="https://www.coingecko.com/pl" hreflang="pl" rel="alternate"/>
# <link href="https://www.coingecko.com/tr" hreflang="tr" rel="alternate"/>
# <link href="https://www.coingecko.com/hu" hreflang="hu" rel="alternate"/>
# <link href="https://www.coingecko.com/nl" hreflang="nl" rel="alternate"/>
# <link href="https://www.coingecko.com/ro" hreflang="ro" rel="alternate"/>
# <link href="https://www.coingecko.com/sv" hreflang="sv" rel="alternate"/>
# <link href="https://www.coingecko.com/cs" hreflang="cs" rel="alternate"/>
# <link href="https://www.coingecko.com/da" hreflang="da" rel="alternate"/>
# <link href="https://www.coingecko.com/el" hreflang="el" rel="alternate"/>
# <link href="https://www.coingecko.com/hi" hreflang="hi" rel="alternate"/>
# <link href="https://www.coingecko.com/no" hreflang="no" rel="alternate"/>
# <link href="https://www.coingecko.com/sk" hreflang="sk" rel="alternate"/>
# <link href="https://www.coingecko.com/uk" hreflang="uk" rel="alternate"/>
# <link href="https://www.coingecko.com/he" hreflang="he" rel="alternate"/>
# <link href="https://www.coingecko.com/fi" hreflang="fi" rel="alternate"/>
# <link href="https://www.coingecko.com/bg" hreflang="bg" rel="alternate"/>
# <link href="https://www.coingecko.com/hr" hreflang="hr" rel="alternate"/>
# <link href="https://www.coingecko.com/lt" hreflang="lt" rel="alternate"/>
# <link href="https://www.coingecko.com/sl" hreflang="sl" rel="alternate"/>
# <link href="https://static.coingecko.com/packs/css/application-b1020f24.chunk.css" media="screen" rel="stylesheet"/>
# <link as="style" href="https://static.coingecko.com/s/fonts-1b338c30f9c32cb3f9d9b5d93651dc6b84c3a7b82a94263376b4f03c327e6cf4.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="https://static.coingecko.com/s/fonts-1b338c30f9c32cb3f9d9b5d93651dc6b84c3a7b82a94263376b4f03c327e6cf4.css" rel="stylesheet"/></noscript>
# <link as="style" href="https://static.coingecko.com/s/secondary-c60783d1cbe3c628a2a89711bfd8f1ec84b7154b9876f9158c8176cce96ae8e1.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="https://static.coingecko.com/s/secondary-c60783d1cbe3c628a2a89711bfd8f1ec84b7154b9876f9158c8176cce96ae8e1.css" rel="stylesheet"/></noscript>
# <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png">
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png">
# <meta content="CoinGecko" name="application-name">
# <meta content="app-id=1390323960" name="apple-itunes-app"/>
# <meta content="wss://cables.coingecko.com/cable" name="action-cable-url">
# <script type="application/ld+json">
#       {
#         "@context":"https://schema.org",
#         "@type":"Organization",
#         "name":"CoinGecko",
#         "description":"CoinGecko provides a fundamental analysis of the crypto market. In addition to tracking price, volume and market capitalisation, CoinGecko tracks community growth, open-source code development, major events and on-chain metrics.",
#         "url":"https://www.coingecko.com/",
#         "logo":"https://static.coingecko.com/s/thumbnail-007177f3eca19695592f0b8b0eabbdae282b54154e1be912285c9034ea6cbaf2.png",
#         "sameAs": [
#             "https://www.facebook.com/coingecko/",
#             "https://twitter.com/coingecko",
#             "https://www.instagram.com/coingecko/",
#             "https://www.youtube.com/channel/UC-OTgwOAI7KmP0eDAtqN3Ow",
#             "https://www.linkedin.com/company/coingecko"
#           ]
#       }
#     </script>
# <script type="application/ld+json">
#       {
#   "@context": "http://schema.org",
#   "@type": "FAQPage",
#   "mainEntity": [
#     {
#       "@type": "Question",
#       "name": "What is Crypto Market Cap?",
#       "acceptedAnswer": {
#         "@type": "Answer",
#         "text": "Crypto market cap is the total value of all the coins of a particular cryptocurrency that have been mined or are in circulation. Market capitalization is used to determine the ranking of cryptocurrencies. The higher the market cap of a particular crypto coin, the higher its ranking and share of the market. Crypto market cap is calculated by multiplying the total number of coins in circulation by its current price. For instance, to calculate the market cap of Ethereum, all you need to do is multiply the total number of Ethereum in circulation by the current price of one Ethereum and you will get its market cap."
#       }
#     },
#     {
#       "@type": "Question",
#       "name": "How to compare Cryptocurrencies Market Cap?",
#       "acceptedAnswer": {
#         "@type": "Answer",
#         "text": "Crypto market cap can be divided into three categories: Large-cap cryptocurrencies (&gt;$10 billion) Mid-cap Cryptocurrencies ($1 billion - $10 billion) Small-cap cryptocurrencies (less then $1 billion). As a financial metric, market cap allows you to compare the total circulating value of one cryptocurrency with another. Large cap cryptocurrencies such as Bitcoin and Ethereum have a market cap of over $10 billion. They typically consist of protocols that have demonstrated track records, and have a vibrant ecosystem of developers maintaining and enhancing the protocol, as well as building new projects on top of them. While market cap is a simple and intuitive comparison metric, it is not a perfect point of comparison. Some cryptocurrency projects may appear to have inflated market cap through price swings and the tokenomics of their supply. As such, it is best to use this metric as a reference alongside other metrics such as trading volume, liquidity, fully diluted valuation, and fundamentals during your research process."
#       }
#     },
#     {
#       "@type": "Question",
#       "name": "How does CoinGecko Calculate Cryptocurrency Prices?",
#       "acceptedAnswer": {
#         "@type": "Answer",
#         "text": "The price is calculated using a global volume-weighted average price formula which is based on the pairings available on different exchanges of a particular crypto asset. For examples and more detailed information on how we track cryptocurrency prices and other metrics, see our methodology page here."
#       }
#     },
#     {
#       "@type": "Question",
#       "name": "Why are Cryptocurrency Prices Different on Exchanges?",
#       "acceptedAnswer": {
#         "@type": "Answer",
#         "text": "You may notice that cryptocurrencies listed on different exchanges have different prices. The reasons for this are complex, but simply put cryptocurrencies are traded on different exchanges and across different markets with varying economic conditions, liquidity, trading pairs, and offerings (e.g. derivatives / leverage) which all influence price in their own way."
#       }
#     },
#     {
#       "@type": "Question",
#       "name": "Where to Check Cryptocurrency Prices?",
#       "acceptedAnswer": {
#         "@type": "Answer",
#         "text": "You can track over 10,000 crypto prices on CoinGecko across more than 50 currencies. Popular cryptocurrency pairs include BTC to USD, ETH to USD, and SLP to PHP. You can also track metrics such as 24 hour trading volume, market capitalization, price chart, historical performance chart, the circulating supply, and more. Sign up to use CoinGecko's crypto portfolio to track the performance of your portfolio. You may also check out GeckoTerminal (currently in beta), our comprehensive multichain on-chain charting tool featuring live charts, current trades, market sentiment and more as it happens in real time! CoinGecko also has a mobile app that enables you to track cryptocurrencies on Android and IOS."
#       }
#     },
#     {
#       "@type": "Question",
#       "name": "What is 24h Volume in the Table Above?",
#       "acceptedAnswer": {
#         "@type": "Answer",
#         "text": "The 24h trading volume refers to the amount a cryptocurrency has been bought and sold on all exchanges within the last 24 hours on the spot market (see derivatives volume here). For instance, if the 24h volume for Ethereum is $15 billion, it means that $15 billion worth of Ether had changed hands across all exchanges in the last 24 hours."
#       }
#     }
#   ]
# }
#     </script>
# <script async="" defer="" src="https://www.googletagmanager.com/gtag/js?id=UA-49392197-1"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', 'UA-49392197-1');
#   </script>
# </meta></meta></link></link></link></link></link></link></link></meta></meta></link></head>
# <body data-action-name="index" data-category-key="" data-coin-name="hp" data-controller="csrf-meta currency price percent-change portfolios portfolio-coin-transactions-new application ads index-trending-coins" data-controller-name="coins" data-currency-override="" data-currency-symbols='{"btc":"BTC","eth":"ETH","ltc":"LTC","bch":"BCH","bnb":"BNB","eos":"EOS","xrp":"XRP","xlm":"XLM","link":"LINK","dot":"DOT","yfi":"YFI","usd":"$","aed":"DH","ars":"$","aud":"A$","bdt":"৳","bhd":"BD","bmd":"$","brl":"R$","cad":"CA$","chf":"Fr.","clp":"CLP$","cny":"¥","czk":"Kč","dkk":"kr.","eur":"€","gbp":"£","hkd":"HK$","huf":"Ft","idr":"Rp","ils":"₪","inr":"₹","jpy":"¥","krw":"₩","kwd":"KD","lkr":"Rs","mmk":"K","mxn":"MX$","myr":"RM","ngn":"₦","nok":"kr","nzd":"NZ$","php":"₱","pkr":"₨","pln":"zł","rub":"₽","sar":"SR","sek":"kr","sgd":"S$","thb":"฿","try":"₺","twd":"NT$","uah":"₴","vef":"Bs.F","vnd":"₫","zar":"R","xdr":"XDR","xag":"XAG","xau":"XAU","bits":"μBTC","sats":"sats"}' data-exchange-rate-json='{"usd":"20114.595","gbp":"17519.812","eur":"20147.241","cny":"140609.067","jpy":"2888916.702","cad":"26526.444","rub":"1199332.728","hkd":"157870.407","sek":"215409.675","sgd":"28320.445","krw":"28112668.82","aud":"29918.328","zar":"352755.21","inr":"1603745.72","myr":"91219.69","idr":"300503678.327","brl":"104583.827","nzd":"33608.169","mxn":"402506.711","php":"1152556.317","dkk":"149830.141","pln":"95283.059","xau":"11.9366043320818","xag":"1038.5211854547","twd":"628223.065","xdr":"14317.126","chf":"19272.859","eth":"12.6318862810839","aed":"73881.612","ars":"2873850.044","kwd":"6215.208","lkr":"7237807.597","sar":"75596.663","try":"367326.706","thb":"741021.693","pkr":"4770084.107","nok":"203690.409","ils":"69307.453","huf":"8215793.807","czk":"494014.241","clp":"18538616.825","bdt":"1949027.735","bhd":"7581.935","bmd":"20114.595","mmk":"42222165.432","vef":"2014.074","bch":"167.362599629852","ltc":"336.907728803149","eos":"13845.6738477597","bnb":"72.8225072009515","xlm":"193919.31090601","xrp":"60065.9841508711","vnd":"475297728.374","uah":"738889.626","byn":"50747.8367914754","link":"2746.69102086516","dot":"2826.8212103327","yfi":"2.25015303898347","ngn":"8621316.722","bits":"1000000.0","sats":"100000000.0"}' data-locale="en">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NP34MX7" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="fixed-bottom mb-md-4 offset-lg-8" data-controller="cookie-note" id="cookie-notice" style="background: rgb(63, 63, 63 ,0.9); color: #fff; display: none;">
# <div class="container lg:tw-p-4 tw-p-6">
# <div class="row">
# <div class="col-md-12 tw-flex">
# <span>
# This website uses cookies for functionality, analytics and advertising purposes as described in our <a href="/en/privacy">Privacy Policy</a>. If you agree to our use of cookies, please continue to use our site.
# </span>
# <div>
# <button class="btn btn-sm btn-danger float-right ml-2" data-action="click-&gt;cookie-note#accept">OK</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tw-hidden" data-controller="app-flyer-banner" data-target="app-flyer-banner.banner">
# <div class="d-block d-sm-none card rounded-0 tw-flex" style="height: 70px;">
# <div class="tw-hidden" data-target="app-flyer-banner.iOSBanner">
# <div class="m-3">
# <div class="row mx-0">
# <div class="col-1 px-0">
# <a data-action="app-flyer-banner#closeBanner">
# <i class="far text-2xl font-light text-lite mt-1 fa-fa fa-times"></i>
# </a>
# </div>
# <div class="col-2 px-0">
# <img alt="coingecko (thumbnail mini)" height="40" loading="lazy" src="https://static.coingecko.com/s/thumbnail-mini-39a2b9a2a44350dfe28af26cef96c450b617315eb1c40b64faad287ba8089843.png" width="40"/>
# </div>
# <div class="col-6 text-wrap px-0">
# <span class="text-normal font-bold">Continue in app</span>
# <br/>
# Track prices in real-time
# </div>
# <div class="col-3 px-0 text-right mt-1">
# <a class="btn btn-primary" href="https://coingecko.app.link/lTInCXLGz4">Open App</a>
# </div>
# </div>
# </div>
# </div>
# <div class="tw-hidden" data-target="app-flyer-banner.androidBanner">
# <div class="m-3">
# <div class="row mx-0">
# <div class="col-1 px-0">
# <a data-action="app-flyer-banner#closeBanner">
# <i class="far text-2xl font-light text-lite mt-1 fa-fa fa-times"></i>
# </a>
# </div>
# <div class="col-2 px-0">
# <img alt="coingecko (thumbnail mini)" height="40" loading="lazy" src="https://static.coingecko.com/s/thumbnail-mini-39a2b9a2a44350dfe28af26cef96c450b617315eb1c40b64faad287ba8089843.png" width="40"/>
# </div>
# <div class="col-6 text-wrap px-0">
# <span class="text-normal font-bold">Continue in app</span>
# <br/>
# Track prices in real-time
# </div>
# <div class="col-3 px-0 text-right mt-1">
# <a class="btn btn-primary" href="https://coingecko.app.link/lTInCXLGz4">Open App</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header dashboard">
# <div class="top-header tw-p-0 tw-flex tw-justify-center tw-items-center" data-controller="top-announcement-header">
# </div>
# <script>
#       // declare darkmode function
#       function applyBackgroundTheme(color) {
#       var css = "html { background: " + color + "; }",
#       head = document.head || document.getElementsByTagName('head')[0],
#       style = document.createElement('style');
#       head.appendChild(style);
#         style.type = 'text/css';
#         if (style.styleSheet){
#           style.styleSheet.cssText = css;
#         } else {
#           style.appendChild(document.createTextNode(css));
#         }
#       }
#       function darkmode() {
#         applyBackgroundTheme("#252525")
#       }
#
#       // Prioritize night mode
#       var isDarkMode = document.cookie.split(';').filter(function(item) { return item.indexOf('is_dark=true') >= 0 }).length
#       if (isDarkMode) {
#         document.body.classList.add('darktheme');
#         darkmode();
#       } else {
#         document.body.classList.remove('darktheme');
#       }
#
#       var isTopAnnouncementHeaderDisabled = document.cookie.split(';').filter(function(item) { return item.indexOf('top_announcement_header_disabled=1') >= 0 }).length
#       if (isTopAnnouncementHeaderDisabled) {
#         document.getElementById("top-announcement-header").style.display = "none";
#       }
#     </script>
# <div class="tw-hidden 2lg:tw-block">
# <div class="nav-border-bottom tw-py-1.5">
# <div class="container tw-flex tw-justify-between tw-items-center tw-text-black tw-text-2xs tw-h-10">
# <span data-target="application.navigationOverallStats" data-url="/en/overall_stats"></span>
# <div class="tw-hidden lg:tw-flex lg:tw-justify-end lg:tw-items-center">
# <div class="tw-flex tw-justify-end tw-items-center">
# <div class="dropdown tw-w-12">
# <span class="tw-cursor-pointer text-black" data-flip="false" data-toggle="dropdown">
# EN <i class="fas fa-caret-down"></i>
# </span>
# <div class="dropdown-menu dropdown-menu-center text-2xs">
# <span class="font-bold dropdown-item bg-transparent py-2">Language</span>
# <div class="tw-flex flex-row">
# <div>
# <a class="dropdown-item py-2" href="/">English</a>
# <a class="dropdown-item py-2" href="/de">Deutsch</a>
# <a class="dropdown-item py-2" href="/es">Español</a>
# <a class="dropdown-item py-2" href="/fr">Français</a>
# <a class="dropdown-item py-2" href="/it">Italiano</a>
# <a class="dropdown-item py-2" href="/pl">język polski</a>
# <a class="dropdown-item py-2" href="/ro">Limba română</a>
# <a class="dropdown-item py-2" href="/hu">Magyar nyelv</a>
# <a class="dropdown-item py-2" href="/nl">Nederlands</a>
# <a class="dropdown-item py-2" href="/pt">Português</a>
# <a class="dropdown-item py-2" href="/sv">Svenska</a>
# <a class="dropdown-item py-2" href="/vi">Tiếng việt</a>
# </div>
# <div>
# <a class="dropdown-item py-2" href="/tr">Türkçe</a>
# <a class="dropdown-item py-2" href="/ru">Русский</a>
# <a class="dropdown-item py-2" href="/ja">日本語</a>
# <a class="dropdown-item py-2" href="/zh">简体中文</a>
# <a class="dropdown-item py-2" href="/zh-tw">繁體中文</a>
# <a class="dropdown-item py-2" href="/ko">한국어</a>
# <a class="dropdown-item py-2" href="/ar">العربية</a>
# <a class="dropdown-item py-2" href="/th">ภาษาไทย</a>
# <a class="dropdown-item py-2" href="/id">Bahasa Indonesia</a>
# <a class="dropdown-item py-2" href="/cs">čeština</a>
# <a class="dropdown-item py-2" href="/da">dansk</a>
# <a class="dropdown-item py-2" href="/el">Ελληνικά</a>
# </div>
# <div>
# <a class="dropdown-item py-2" href="/hi">हिंदी</a>
# <a class="dropdown-item py-2" href="/no">norsk</a>
# <a class="dropdown-item py-2" href="/sk">slovenský jazyk</a>
# <a class="dropdown-item py-2" href="/uk">украї́нська мо́ва</a>
# <a class="dropdown-item py-2" href="/he">עִבְרִית</a>
# <a class="dropdown-item py-2" href="/fi">suomen kieli</a>
# <a class="dropdown-item py-2" href="/bg">български</a>
# <a class="dropdown-item py-2" href="/hr">hrvatski</a>
# <a class="dropdown-item py-2" href="/lt">lietuvių kalba</a>
# <a class="dropdown-item py-2" href="/sl">slovenski jezik</a>
# </div>
# </div>
# </div>
# </div>
# <span class="tw-w-16" data-target="application.navigationCurrency" data-url="/en/navigations/currency_selector"></span>
# <div data-controller="dark">
# <button class="border-0 p-0 text-2xs bg-transparent text-black" data-action="click-&gt;dark#toggle" type="button">
# <i class="fas text-2xs fa-moon" data-dark-class-name="fa-sun" data-light-class-name="fa-moon" data-target="dark.icon" type="solid"></i>
# </button>
# </div>
# <span class="tw-w-24">
# <div class="tailwind-reset">
# <a class="tw-ml-4 tw-hidden dark:hover:tw-bg-opacity-5 dark:tw-text-primary-500 disabled:tw-opacity-50 focus:tw-border-opacity-0 focus:tw-outline-none focus:tw-ring-2 focus:tw-ring-offset-0 focus:tw-ring-primary-500 focus:tw-text-primary-500 hover:tw-bg-primary-50 hover:tw-text-primary-500 tw-bg-transparent tw-border tw-border-primary-500 tw-font-medium tw-inline-flex tw-items-center tw-leading-4 tw-rounded-md tw-text-primary-500 tw-justify-center tw-px-2.5 tw-py-1.5 tw-text-xs" data-target="csrf-meta.subscribeButton" data-view-component="true" href="/en/premium/pricing" role="button">
# Subscribe
# </a>
# </div>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="nav-border-bottom">
# <div class="container 2lg:tw-hidden tw-py-2 tw-flex tw-justify-between tw-items-center">
# <div>
# <a class="text-body text-2xl" data-target="#mobile-user-menu" data-toggle="modal" href="#"><i class="far fa-bars"></i></a>
# <div class="modal" id="mobile-user-menu">
# <div class="modal-dialog h-sm-100 sm-m-0">
# <div class="modal-content h-sm-100 rounded-0 tw-flex flex-column h-sm-100 tw-py-2 tw-px-4">
# <div class="tw-flex tw-justify-between tw-items-center pb-2">
# <div>
# <button class="close float-left h3 font-light text-black" data-dismiss="modal" type="button">
# <i class="far fa-times"></i>
# </button>
# </div>
# <div class="darkhide tw-text-center">
# <a href="/">
# <img alt="CoinGecko Logo" height="39" src="https://static.coingecko.com/s/coingecko-logo-8903d34ce19ca4be1c81f0db30e924154750d208683fad7ae6f2ce06c76d0a56.png" width="140"/>
# </a></div>
# <div class="darkshow tw-text-center">
# <a href="/">
# <img alt="CoinGecko Logo (White)" height="39" loading="lazy" src="https://static.coingecko.com/s/coingecko-logo-white-ea42ded10e4d106e14227d48ea6140dc32214230aa82ef63d0499f9c1e109656.png" width="140"/>
# </a></div>
# <div>
# <a class="tw-text-sm tw-text-black tw-hidden" data-target="csrf-meta.subscribeButton" href="/en/premium/pricing">
# <div class="tw-flex tw-justify-between tw-items-center">
# Subscribe
# </div>
# </a> </div>
# </div>
# <div class="tw-flex flex-column">
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseCoins">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# Cryptocurrencies
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseCoins">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-2 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/">By Market Cap</a>
# <a class="text-black" href="/en/new-cryptocurrencies">New Cryptocurrencies</a>
# <a class="text-black" href="/en/categories">Categories</a>
# <a class="text-black" href="/en/watchlists">Watchlists</a>
# <a class="text-black" href="/en/crypto-gainers-losers">Gainers &amp; Losers</a>
# <a class="text-black" href="/en/watchlists/high-volume">High Volume</a>
# <a class="text-black" href="/en/all-cryptocurrencies">All Coins</a>
# <a class="text-black" href="/en/compare-cryptocurrencies">Compare Coins</a>
# <a class="text-black" href="/en/global-charts">Global Chart</a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseExchanges">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# Exchanges
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseExchanges">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-2 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/en/exchanges">Crypto Exchanges</a>
# <a class="text-black" href="/en/exchanges/decentralized">Decentralized Exchanges</a>
# <a class="text-black" href="/en/exchanges/derivatives">Derivatives</a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseNft">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# NFT
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseNft">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-2 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/en/nft">NFT Floor Price</a>
# <a class="text-black" href="/en/categories/non-fungible-tokens-nft">NFT Related Coins</a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapsePublications">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# Learn Crypto
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapsePublications">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-2 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/learn">All Crypto Articles</a>
# <a class="text-black" href="/learn/category/analysis">Analysis</a>
# <a class="text-black" href="/learn/category/guides">Guides</a>
# <a class="text-black" href="/en/glossary">Glossary</a>
# <a class="text-black" href="/en/methodology">Methodology</a>
# <a class="text-black" href="https://www.youtube.com/c/CoinGeckoTV?sub_confirmation=1">Videos</a>
# <a class="text-black" href="https://podcast.coingecko.com/">Podcast</a>
# <a class="text-black" href="https://landing.coingecko.com/newsletter">Newsletter</a>
# <a class="text-black tw-flex-1" data-report-link="/en/publications/reports" data-target="csrf-meta.reportLink" href="https://landing.coingecko.com/reports"><span class="translation_missing" title="translation missing: en.layouts.navigation.mobile.research_reports">Research Reports</span></a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseProducts">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# Products
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseProducts">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-2 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/premium?locale=en">CoinGecko Premium</a>
# <a class="text-black" href="/en/mobile">CoinGecko App</a>
# <a class="text-black" href="/en/portfolio">Crypto Portfolio</a>
# <a class="text-black" href="/en/api">Crypto API</a>
# <a class="text-black" href="/en/widgets">Crypto Widget</a>
# <a class="text-black" href="https://store.coingecko.com/">CoinGecko Store</a>
# <a class="text-black" href="https://landing.coingecko.com/geckocon-2022/">GeckoCon 2022</a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" href="/en/portfolio">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# Portfolio
# <span class="tw-inline-flex tw-items-center tw-font-medium tw-bg-primary-100 tw-text-primary-800 hover:tw-bg-primary-200 hover:tw-text-primary-900 dark:tw-bg-white dark:tw-bg-opacity-12 hover:dark:tw-bg-opacity-24 dark:tw-text-primary-400 tw-px-2 tw-py-0.5 tw-rounded tw-text-xs tw-max-h-5 tw-ml-1" data-view-component="true">
# Start your portfolio now
# </span> </div>
# </a>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseExplore">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# Explore
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseExplore">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-2 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/en/coins/bitcoin">Bitcoin Price</a>
# <a class="text-black" href="/en/coins/ethereum">Ethereum Price</a>
# <a class="text-black" href="/en/categories/decentralized-finance-defi">DeFi Coins</a>
# <a class="text-black" href="/en/categories/metaverse">Metaverse Coins</a>
# <a class="text-black" href="/en/categories/gaming">Gaming Coins</a>
# <a class="text-black" href="/en/categories/meme-token">Meme Coins</a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseResources">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# Resources
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseResources">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-2 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/en/derivatives">Perpetuals</a>
# <a class="text-black" href="/en/news">Crypto News</a>
# <a class="text-black" href="/en/public-companies-bitcoin">Bitcoin Treasury</a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" href="https://www.geckoterminal.com?utm_source=coingecko&amp;utm_medium=referral&amp;utm_campaign=mobile_navigation" rel="noopener" target="_blank">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom tw-py-4">
# GeckoTerminal
# <span class="tw-inline-flex tw-items-center tw-font-medium tw-bg-primary-100 tw-text-primary-800 hover:tw-bg-primary-200 hover:tw-text-primary-900 dark:tw-bg-white dark:tw-bg-opacity-12 hover:dark:tw-bg-opacity-24 dark:tw-text-primary-400 tw-px-2 tw-py-0.5 tw-rounded tw-text-xs tw-max-h-5 tw-ml-1" data-view-component="true">
# New
# </span> </div>
# </a>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseAboutUs">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom py-3">
# About CoinGecko
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseAboutUs">
# <div class="text-normal border-bottom tw-p-4">
# <div class="tw-grid tw-grid-cols-1 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="/en/about">About Us</a>
# <a class="text-black" href="/en/careers">Careers</a>
# <a class="text-black" href="/en/branding">Branding Guide</a>
# </div>
# </div>
# </div>
# <a class="text-normal text-black" data-toggle="collapse" href="#collapseHelp">
# <div class="tw-flex tw-justify-between tw-items-center border-bottom py-3">
# Help
# <i class="fas fa-caret-down text-black"></i>
# </div>
# </a>
# <div class="collapse transition-none" id="collapseHelp">
# <div class="text-normal border-bottom tw-p-4 mb-3">
# <div class="tw-grid tw-grid-cols-1 tw-gap-x-8 tw-gap-y-4">
# <a class="text-black" href="https://support.coingecko.com">Help Center</a>
# <a class="text-black" href="/en/faq">FAQ</a>
# <a class="text-black" href="https://hackenproof.com/coingecko/coingecko">Bug Bounty</a>
# </div>
# </div>
# </div>
# </div>
# <div class="tw-flex tw-gap-x-2 tw-items-center mt-4 tailwind-reset">
# <div class="dropdown tw-inline-flex tw-items-center tw-justify-center tw-w-1/3 tw-py-2 tw-border tw-border-gray-300 tw-text-sm tw-leading-4 tw-font-medium tw-rounded-md tw-text-gray-700 tw-bg-transparent hover:tw-bg-gray-50 hover:tw-border-gray-400 focus:tw-outline-none focus:tw-ring-2 focus:tw-ring-offset-0 focus:tw-ring-primary-500 focus:tw-border-opacity-0 dark:tw-text-white dark:tw-text-opacity-87 dark:hover:tw-bg-white dark:hover:tw-bg-opacity-5 dark:tw-border-white dark:tw-border-opacity-12 dark:hover:tw-border-opacity-24 tw-shadow-sm">
# <a class="tw-w-full tw-inline-flex tw-justify-center tw-text-gray-700 dark:tw-text-white dark:tw-text-opacity-87" data-toggle="dropdown" href="#">
# EN
# </a>
# <div class="dropdown-menu dropdown-popup dropdown-menu-content">
# <div class="ml-1 row mb-4 mr-0 mt-2">
# <span class="col-2">
# <i class="far mr-1 dropdown-close-button text-black fa-fa fa-long-arrow-left fa-lg"></i>
# </span>
# <span class="dropdown-menu-secondary-title center col-8">Language</span>
# </div>
# <div class="tw-flex flex-column">
# <div>
# <a class="dropdown-item py-2" href="/">English</a>
# <a class="dropdown-item py-2" href="/de">Deutsch</a>
# <a class="dropdown-item py-2" href="/es">Español</a>
# <a class="dropdown-item py-2" href="/fr">Français</a>
# <a class="dropdown-item py-2" href="/it">Italiano</a>
# <a class="dropdown-item py-2" href="/pl">język polski</a>
# <a class="dropdown-item py-2" href="/ro">Limba română</a>
# <a class="dropdown-item py-2" href="/hu">Magyar nyelv</a>
# <a class="dropdown-item py-2" href="/nl">Nederlands</a>
# <a class="dropdown-item py-2" href="/pt">Português</a>
# <a class="dropdown-item py-2" href="/sv">Svenska</a>
# </div>
# <div>
# <a class="dropdown-item py-2" href="/vi">Tiếng việt</a>
# <a class="dropdown-item py-2" href="/tr">Türkçe</a>
# <a class="dropdown-item py-2" href="/ru">Русский</a>
# <a class="dropdown-item py-2" href="/ja">日本語</a>
# <a class="dropdown-item py-2" href="/zh">简体中文</a>
# <a class="dropdown-item py-2" href="/zh-tw">繁體中文</a>
# <a class="dropdown-item py-2" href="/ko">한국어</a>
# <a class="dropdown-item py-2" href="/ar">العربية</a>
# <a class="dropdown-item py-2" href="/th">ภาษาไทย</a>
# <a class="dropdown-item py-2" href="/id">Bahasa Indonesia</a>
# <a class="dropdown-item py-2" href="/cs">čeština</a>
# </div>
# <div>
# <a class="dropdown-item py-2" href="/da">dansk</a>
# <a class="dropdown-item py-2" href="/el">Ελληνικά</a>
# <a class="dropdown-item py-2" href="/hi">हिंदी</a>
# <a class="dropdown-item py-2" href="/no">norsk</a>
# <a class="dropdown-item py-2" href="/sk">slovenský jazyk</a>
# <a class="dropdown-item py-2" href="/uk">украї́нська мо́ва</a>
# <a class="dropdown-item py-2" href="/he">עִבְרִית</a>
# <a class="dropdown-item py-2" href="/fi">suomen kieli</a>
# <a class="dropdown-item py-2" href="/bg">български</a>
# <a class="dropdown-item py-2" href="/hr">hrvatski</a>
# <a class="dropdown-item py-2" href="/lt">lietuvių kalba</a>
# </div>
# <div>
# <a class="dropdown-item py-2" href="/sl">slovenski jezik</a>
# </div>
# </div>
# </div>
# </div>
# <div class="tw-inline-flex tw-items-center tw-justify-center tw-w-1/3 tw-py-2 tw-border tw-border-gray-300 tw-text-sm tw-leading-4 tw-font-medium tw-rounded-md tw-text-gray-700 tw-bg-transparent hover:tw-bg-gray-50 hover:tw-border-gray-400 focus:tw-outline-none focus:tw-ring-2 focus:tw-ring-offset-0 focus:tw-ring-primary-500 focus:tw-border-opacity-0 dark:tw-text-white dark:tw-text-opacity-87 dark:hover:tw-bg-white dark:hover:tw-bg-opacity-5 dark:tw-border-white dark:tw-border-opacity-12 dark:hover:tw-border-opacity-24 tw-shadow-sm" data-controller="currency-dropdown">
# <a class="tw-w-full tw-inline-flex tw-justify-center tw-text-gray-700 dark:tw-text-white dark:tw-text-opacity-87" data-toggle="dropdown" href="#">
# <span data-target="currency-dropdown.button">USD</span>
# </a>
# <div class="dropdown-menu dropdown-popup dropdown-menu-content">
# <div data-controller="searchable" data-target="currency-dropdown.currencyList searchable.itemList">
# <div class="d-lg-none ml-1 row mb-3 mr-0 mt-2">
# <span class="col-2">
# <i class="far mr-1 dropdown-close-button text-black fa-fa fa-long-arrow-left fa-lg"></i>
# </span>
# <span class="dropdown-menu-secondary-title center col-8">Currencies</span>
# </div>
# <div class="col-12 col-lg-5 mt-2">
# <input class="form-control text-normal currency-selector-search-bar tw-border tw-border-gray-300 dark:tw-bg-black" data-action="keyup-&gt;searchable#filterItems click-&gt;searchable#preventCollapse" data-target="searchable.searchInput" placeholder="Search..." type="text"/>
# </div>
# <div class="pt-3 pb-2">
# <span class="ml-3 dropdown-menu-secondary-title">Cryptocurrencies</span>
# </div>
# <ul class="tw-flex flex-wrap p-0 m-0 b-b nav pb-2">
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="btc">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">BTC</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Bitcoin</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="eth">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">ETH</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Ether</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="ltc">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">LTC</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Litecoin</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="bch">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">BCH</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Bitcoin Cash</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="bnb">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">BNB</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Binance Coin</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="eos">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">EOS</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">EOS</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="xrp">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">XRP</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">XRP</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="xlm">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">XLM</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Lumens</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="link">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">LINK</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Chainlink</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="dot">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">DOT</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Polkadot</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="yfi">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">YFI</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Yearn.finance</span>
# </div>
# </div> </li>
# </ul>
# <div class="pt-3 pb-2">
# <span class="ml-3 dropdown-menu-secondary-title">Bitcoin Units <span class="badge bg-warning text-dark">New</span></span>
# </div>
# <ul class="tw-flex flex-wrap p-0 m-0 b-b nav pb-2">
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="bits">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">BITS</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Bits</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="sats">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">SATS</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Satoshi</span>
# </div>
# </div> </li>
# </ul>
# <div class="pt-3 pb-2">
# <span class="ml-3 dropdown-menu-secondary-title">Suggested Currencies</span>
# </div>
# <ul class="tw-flex flex-wrap p-0 m-0 b-b nav pb-2">
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="usd">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">USD</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">US Dollar</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="idr">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">IDR</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Indonesian Rupiah</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="twd">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">TWD</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">New Taiwan Dollar</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="eur">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">EUR</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Euro</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="krw">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">KRW</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">South Korean Won</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="jpy">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">JPY</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Japanese Yen</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="rub">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">RUB</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Russian Ruble</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="cny">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">CNY</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Chinese Yuan</span>
# </div>
# </div> </li>
# </ul>
# <div class="pt-3 pb-2">
# <span class="ml-3 mb-0 dropdown-menu-secondary-title">Fiat Currencies</span>
# </div>
# <ul class="tw-flex flex-wrap p-0 m-0 b-b nav pb-2">
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="aed">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">AED</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">United Arab Emirates Dirham</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="ars">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">ARS</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Argentine Peso</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="aud">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">AUD</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Australian Dollar</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# <div class="py-1 px-3 mb-2 currency tw-cursor-pointer dropdown-option" data-action="click-&gt;currency-dropdown#selectCurrency" data-iso-code="bdt">
# <div class="justify-content-md-between">
# <span class="text-muted" style="display: inline-block; width: 25px;">BDT</span>
# <br class="d-block d-sm-none"/>
# <span class="d-md-inline currency-name">Bangladeshi Taka</span>
# </div>
# </div> </li>
# <li class="col-6 col-md-3 col-lg-4">
# ...
# Donations
# </div>
# <div class="tw-text-sm">
# <div class="tw-mb-3">
# <a data-target="#bitcoinDonationsModal" data-toggle="modal" href="#">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Bitcoin</span>
# </a>
# <div class="modal" id="bitcoinDonationsModal">
# <div class="modal-dialog">
# <div class="modal-content rounded-0 modal-body mx-2">
# <div class="tw-flex flex-column" data-controller="user-login-modal">
# <div class="my-2">
# <button class="close float-left mr-3" data-dismiss="modal" type="button">
# <span class="text-5xl font-light" style="color: #707070;">×</span>
# </button>
# <span class="text-2xl text-black font-semibold">Donate Bitcoin</span>
# </div>
# <div class="tw-mx-auto">
# <img class="mt-1" height="200" loading="lazy" src="https://static.coingecko.com/s/donations_qrcode/bitcoin_address-0c641f25960938f692e238c986cf0719ea871e94617dd28202823ae8ffa14a74.png" width="200"/>
# <hr/>
# </div>
# <div class="mb-2">
# <small class="form-text text-black text-sm">Donation Address</small>
# </div>
# <div class="input-group input-group-sm" data-controller="footer">
# <input class="form-control font-semibold" data-target="footer.address" readonly="" style="height:48px;" type="text" value="3KJmVaMzKRxKbKTMQmfnKzecpsExs8tbkk"/>
# <div class="input-group-append">
# <button class="btn btn-secondary" data-action="footer#copyAddress" style="height: 48px;width: 48px"><i class="far fa-copy text-2xl" data-target="footer.buttonIcon"></i></button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tw-mb-3">
# <a data-target="#ethereumDonationsModal" data-toggle="modal" href="#">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Ethereum</span>
# </a>
# <div class="modal" id="ethereumDonationsModal">
# <div class="modal-dialog">
# <div class="modal-content rounded-0 modal-body mx-2">
# <div class="tw-flex flex-column" data-controller="user-login-modal">
# <div class="my-2">
# <button class="close float-left mr-3" data-dismiss="modal" type="button">
# <span class="text-5xl font-light" style="color: #707070;">×</span>
# </button>
# <span class="text-2xl text-black font-semibold">Donate Ethereum</span>
# </div>
# <div class="tw-mx-auto">
# <img class="mt-1" height="200" loading="lazy" src="https://static.coingecko.com/s/donations_qrcode/ethereum_address-5e5ffeae71cb953fc5b12ebdf4205060a60bd35338de0465cad78ddf78db5c9d.png" width="200"/>
# <hr/>
# </div>
# <div class="mb-2">
# <small class="form-text text-black text-sm">Donation Address</small>
# </div>
# <div class="input-group input-group-sm" data-controller="footer">
# <input class="form-control font-semibold" data-target="footer.address" readonly="" style="height:48px;" type="text" value="0x4Cdc86fa95Ec2704f0849825f1F8b077deeD8d39"/>
# <div class="input-group-append">
# <button class="btn btn-secondary" data-action="footer#copyAddress" style="height: 48px;width: 48px"><i class="far fa-copy text-2xl" data-target="footer.buttonIcon"></i></button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tw-flex tw-flex-col tw-mt-2">
# <div class="tw-text-sm tw-text-white tw-text-opacity-87 tw-mb-3">
# About CoinGecko
# </div>
# <div class="tw-text-sm">
# <div class="tw-mb-3">
# <a href="/en/about">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">About Us</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="/en/careers">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Careers</span>
# <span class="badge badge-success tw-bg-primary-100 tw-text-primary-800 tw-ml-1 tw-mb-1">Join Us</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://blog.coingecko.com/" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Company Blog</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="/en/branding">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Branding Guide</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://www.coingecko.com/request">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Request Form</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://gcko.io/coingeckoads">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Advertising</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="/en/faq">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">FAQ</span>
# </a> </div>
# </div>
# </div>
# <div class="tw-flex tw-flex-col tw-mt-2">
# <div class="tw-text-sm tw-text-white tw-text-opacity-87 tw-mb-3">
# Community
# </div>
# <div class="tw-text-sm">
# <div class="tw-mb-3">
# <a href="https://twitter.com/coingecko" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Twitter</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://t.me/coingecko" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Telegram Chat</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://t.me/coingeckonews" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Telegram News</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://www.instagram.com/coingecko/" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Instagram</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://www.reddit.com/r/coingecko/" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Reddit</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://discord.gg/EhrkaCH" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Discord</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://www.facebook.com/coingecko" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Facebook</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://www.youtube.com/channel/UC-OTgwOAI7KmP0eDAtqN3Ow?sub_confirmation=1" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">Youtube</span>
# </a> </div>
# <div class="tw-mb-3">
# <a href="https://www.tiktok.com/@coingeckotv" rel="noopener" target="_blank">
# <span class="tw-text-white tw-text-opacity-60 hover:tw-text-opacity-87">TikTok</span>
# </a> </div>
# </div>
# </div>
# <div class="tw-col-span-2 tw-flex tw-flex-col tw-justify-between tw-mt-2 tw-text-sm">
# <div>
# <div class="tw-text-white tw-text-opacity-87 tw-mb-3">
# Interested to stay up-to-date with cryptocurrencies?
# </div>
# <div class="tw-mb-3 tw-text-white tw-text-opacity-60">
# Get the latest crypto news, updates, and reports by subscribing to our free newsletter.
# </div>
# <form data-controller="newsletter">
# <div class="tw-mb-2">
# <input class="form-control rounded-1 tw-mb-1" data-target="newsletter.email" placeholder="Enter Your Email" type="email"/>
# <input data-target="newsletter.campaignId" type="hidden" value="w"/>
# <span data-target="newsletter.emailLabel"><div id="canvas"></div></span>
# </div>
# <div class="tw-mb-5">
# <input class="btn btn-primary btn-lg rounded-1" data-action="newsletter#subscribeNewsletter" data-disable-with="Subscribe" data-success-text="Congratulations! You did it." data-target="newsletter.submitButton" name="commit" type="submit" value="Subscribe">
# </input></div>
# </form>
# </div>
# <div>
# <div class="tw-mb-3 tw-text-white tw-text-opacity-87">
# Download our app now
# </div>
# <div class="tw-flex tw-flex-row">
# <a href="https://coingecko.app.link/footer-android" rel="nofollow noopener" target="_blank">
# <img alt="Google Play Store Button" class="tw-mr-2" height="40" loading="lazy" src="https://static.coingecko.com/s/coingecko_logos/google_play_store-cb1f298b04afa7f74639a948d9b2e22e4aa6eea9486a2b0442c2cf9bdcda63e8.svg" width="135"/>
# </a> <a href="https://coingecko.app.link/footer-ios" rel="nofollow noopener" target="_blank">
# <img alt="Apple App Store Button" class="tw-mr-2" height="40" loading="lazy" src="https://static.coingecko.com/s/coingecko_logos/apple_app_store-558245a688cc13737dfb861fd82b252d75d5afbaf343c06e3067a454675bbe05.svg" width="135"/>
# </a> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="d-block d-lg-none py-2">
# <div class="center">
# <a class="text-white" href="/en/disclaimer">Disclaimer</a>
# <span class="mx-1">•</span>
# <a class="text-white" href="/en/terms">Terms of Service</a>
# <span class="mx-1">•</span>
# <a class="text-white" href="/en/privacy">Privacy Policy</a>
# </div>
# <div class="center mt-2">
# © 2022 CoinGecko. All Rights Reserved.
# </div>
# </div>
# </footer>
# <div class="toast toast-hide m-4 p-3" data-controller="toast">
# <div class="notice" data-target="toast.notice"></div>
# </div>
# <div class="tw-hidden" data-controller="firebase-fcm" data-fcm-sender-id="359303784940" id="firebaseFCM"></div>
# <div data-controller="gecko-guide-modal" data-gecko-guide-modal-version="11" x-data="{ open: false }">
# <div class="tw-hidden tw-fixed tw-z-50 tw-mr-3 tw-mb-14 tw-right-0 tw-bottom-0" data-gecko-guide-modal-target="geckoButton" id="geckoFloat">
# <div @click="open = true" class="tw-static tw-mr-2.5 tw-mb-2" data-action="click-&gt;gecko-guide-modal#clickGeckoGuide" x-cloak="" x-show="!open">
# <div class="tw-invisible tw-absolute tw-top-0 tw-left-0 tw-rounded-full tw-bg-primary-200 tw-opacity-50 tw-flex tw-p-6 tw-relative" data-gecko-guide-modal-target="geckoButtonPing"></div>
# <div class="tw-absolute tw-top-0.5 tw-left-0.5 tw-cursor-pointer tw-z-20">
# <img class="tw-w-11 tw-h-11 tw-filter tw-drop-shadow-geckoguide" src="https://static.coingecko.com/s/gecko_guide-39a2c2f54f1aec011272744a4de4cd07499a18e9814078ae2d9ada38f5a2f162.svg"/>
# </div>
# </div>
# <div @click="open = false" class="tw-hidden sm:tw-block tw-cursor-pointer tw-z-20 tw-w-10 tw-h-10 tw-mb-3 tw-mr-3 tw-left-0 tw-top-0 tw-bg-primary-500 tw-rounded-full" data-action="click-&gt;gecko-guide-modal#submitHideDialogForm" x-cloak="" x-show="open">
# <span class="tw-text-2xl tw-text-white center tw-pt-2"><i class="far fa-times"></i></span>
# </div>
# </div>
# <div class="tw-fixed tw-z-10 tw-inset-0 tw-bg-black tw-bg-opacity-75 tw-overflow-y-auto tw-h-full tw-w-full" data-action="click-&gt;gecko-guide-modal#submitHideDialogForm" id="my-modal" x-cloak="" x-show="open" x-transition:enter="tw-transition tw-transition-opacity tw-ease-out tw-duration-300" x-transition:enter-end="tw-opacity-100 tw-transform " x-transition:enter-start="tw-opacity-0 tw-transform " x-transition:leave="tw-transition tw-ease-in tw-duration-300" x-transition:leave-end="tw-opacity-0 tw-transform ">
# </div>
# <div @click.away="open = false" class="tw-fixed tw-z-20 gecko-guide-dialog-position md:tw-bottom-16 tw-mr-3 md:tw-right-16 md:tw-mt-4 tw-border tw-w-full md:tw-w-auto tw-h-full md:tw-h-auto md:tw-w-96 md:tw-shadow-lg md:tw-rounded-md tw-bg-white dark:tw-bg-dark-10 dark:tw-text-white tw-overflow-hidden tw-overflow-y-auto" x-cloak="" x-show="open" x-transition:enter="tw-transition tw-ease-out tw-duration-300" x-transition:enter-end="tw-opacity-100 tw-transform tw-translate-y-0" x-transition:enter-start="tw-opacity-0 tw-transform tw--translate-y-5" x-transition:leave="tw-transition tw-ease-in tw-duration-300" x-transition:leave-end="tw-opacity-0 tw-transform tw--translate-y-5">
# <div class="tw-mt-6 tw-ml-6 md:tw-hidden">
# <span @click="open = false" class="tw-text-2xl tw-text-gray-400 dark:tw-text-white" data-action="click-&gt;gecko-guide-modal#submitHideDialogForm"><i class="far fa-times"></i></span>
# </div>
# <div class="tw-px-5 tw-py-4 tw-items-center center">
# <a href="https://gcko.io/tejg1dh" target="_blank">
# <img class="tw-h-40" loading="lazy" src="https://static.coingecko.com/s/tokenomics_video_banner-e176c4ba0eaff748dfebc19c3cd7b64afde6a6fbdad083afc1a7bd8ec9bbe281.png" style="width: 340px;"/>
# </a> </div>
# <div class="tw-grid tw-px-5 tw-pt-2 tw-pb-4">
# <a class="dark:focus:tw-outline-none dark:focus:tw-text-white dark:hover:tw-bg-primary-400 dark:hover:tw-text-white dark:tw-text-white disabled:tw-opacity-50 focus:tw-outline-none focus:tw-text-white hover:tw-bg-primary-700 hover:tw-text-white tw-bg-primary-500 tw-border tw-border-transparent tw-font-medium tw-inline-flex tw-items-center tw-leading-4 tw-rounded-md tw-text-white tw-justify-center tw-flex tw-w-full tw-py-3.5 tw-text-sm" data-view-component="true" href="https://gcko.io/f04zgpo" role="button" target="_blank">
# Watch and Learn Crypto
# </a>
# </div>
# <hr class="md:tw-my-0 dark:tw-border-white dark:tw-border-opacity-12"/>
# <a href="https://www.coingecko.com/premium">
# <div class="tw-px-5 tw-py-4">
# <div class="tw-text-lg tw-leading-6 tw-font-medium tw-text-gray-900 dark:tw-text-white">Looking for the latest alphas?</div>
# <div class="tw-text-sm tw-text-gray-500 tw-mb-3 dark:tw-text-gray-400">
# Access exclusive reports by CoinGecko analysts!
# </div>
# <div class="tw-text-primary-500 tw-underline">CoinGecko Premium</div>
# </div>
# </a> <hr class="md:tw-my-0 dark:tw-border-white dark:tw-border-opacity-12"/>
# <a href="https://www.coingecko.com/learn">
# <div class="tw-px-5 tw-py-4">
# <div class="tw-text-lg tw-leading-6 tw-font-medium tw-text-gray-900 dark:tw-text-white">Want to learn more about crypto?</div>
# <div class="tw-text-sm tw-text-gray-500 tw-mb-3 dark:tw-text-gray-400">
# Read beginner-friendly guides &amp; articles.
# </div>
# <div class="tw-text-primary-500 tw-underline">Learn Cryptocurrency</div>
# </div>
# </a> <hr class="md:tw-my-0 dark:tw-border-white dark:tw-border-opacity-12"/>
# <a href="https://support.coingecko.com">
# <div class="tw-px-5 tw-py-4">
# <div class="tw-text-lg tw-leading-6 tw-font-medium tw-text-gray-900 dark:tw-text-white">Need Help?</div>
# <div class="tw-text-sm tw-text-gray-500 tw-mb-3 dark:tw-text-gray-400">
# Find the answers that you need in our Help Centre.
# </div>
# <div class="tw-text-primary-500 tw-underline">Help Centre</div>
# </div>
# </a> <hr class="md:tw-my-0 dark:tw-border-white dark:tw-border-opacity-12"/>
# <form action="index.html" class="tw-px-5 tw-py-4 tw-inline-block tw-align-baseline tw-leading-3">
# <span class="tw-mt-2">
# <input classes="tw-w-4 tw-h-4" data-gecko-guide-modal-target="hideDialogCheckbox" id="hideGeckoGuideCheckbox" type="checkbox"/>
# </span>
# <label class="tw-text-sm tw-ml-2 tw-inline-block tw-leading-3" for="hideGeckoGuideCheckbox">Don't show me for 7 days</label><br/>
# </form>
# </div>
# </div>
# <div class="btn btn-secondary position-fixed" id="toTop" style="bottom:0; margin-bottom:1.5rem; right:0; margin-right:1.5rem"> <span></span><i class="fa fa-arrow-to-top"></i></div>
# <script async="async" defer="defer" src="https://static.coingecko.com/s/application-dddd30c7b4dee9c99b889e3d9146d654591339636c11745beac3cdff40da0908.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/runtime~application-7e06f5b086274f79848b.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/0-2d6b0b18e7485d214e04.chunk.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/2-d0dfb638d4535ff86a53.chunk.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/application-a34aaa7e4e360d2e9cee.chunk.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/runtime~coins-ecc20b21a61193038276.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/0-2d6b0b18e7485d214e04.chunk.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/2-d0dfb638d4535ff86a53.chunk.js"></script>
# <script async="async" defer="defer" src="https://static.coingecko.com/packs/js/coins-4de779031fc742ed2754.chunk.js"></script>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"74b16a624be9d1f4","token":"ca697cea96514f4093039c105354b47b","version":"2022.8.1","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194"></script>
# </body>
# </html>

# %% [markdown]
# ## results

# %%
results = soup.find('table',{'class':'sort table mb-0 text-sm text-lg-normal table-scrollable'}).find('tbody').find_all('tr')

# %%
len(results)
# Out:
# 100

# %% [markdown]
# ## necessary data

# %%
#name
#price
#change_1h
#change_24h
#change_7d
#24h volume
#mkt_cap

# %% [markdown]
# ## name

# %%
results[0].find('span',{'class':'lg:tw-flex font-bold tw-items-center tw-justify-between'}).get_text().strip()
# Out:
# 'Bitcoin'

# %% [markdown]
# ## price

# %%
results[0].find('td',{'class':'td-price price text-right'}).get_text().strip()
# Out:
# '$20,098.22'

# %% [markdown]
# ## 1h change

# %%
results[0].find('td',{'class':'td-change1h change1h stat-percent text-right col-market'}).get_text().strip()
# Out:
# '-0.4%'

# %% [markdown]
# ## 24h change

# %%
results[0].find('td',{'class':'td-change24h'}).get_text().strip()
# Out:
# '-0.8%'

# %% [markdown]
# ## 7d change

# %%
results[0].find('td',{'class':'td-change7d'}).get_text().strip()
# Out:
# '4.2%'

# %% [markdown]
# ## 24h volume

# %%
results[0].find('td',{'class':'td-liquidity_score'}).get_text().strip()
# Out:
# '$37,166,371,696'

# %% [markdown]
# ## market cap

# %%
results[0].find('td',{'class':'td-market_cap cap col-market cap-price text-right'}).get_text().strip()
# Out:
# '$385,327,115,539'

# %% [markdown]
# ## put everything together inside a for loop

# %%
name = []
price = []
change_1h = []
change_24h = []
change_7d = []
volume_24h = []
market_cap = []

for result in results:
    #name
    try:
        name.append(result.find('span',{'class':'lg:tw-flex font-bold tw-items-center tw-justify-between'}).get_text().strip())
    except:
        name.append('n/a')
        #price
    try:
        price.append(result.find('td',{'class':'td-price price text-right'}).get_text().strip())
    except:
        price.append('n/a')
        #1h_change
    try:
        change_1h.append(result.find('td',{'class':'td-change1h change1h stat-percent text-right col-market'}).get_text().strip())
    except:
        change_1h.append('n/a')
        #24h_change
    try:
        change_24h.append(result.find('td',{'class':'td-change24h'}).get_text().strip())
    except:
        change_24h.append('n/a')
        #7d_change
    try:
        change_7d.append(result.find('td',{'class':'td-change7d'}).get_text().strip())
    except:
        change_7d.append('n/a')
        #volume_24h
    try:
        volume_24h.append(result.find('td',{'class':'td-liquidity_score'}).get_text().strip())
    except:
        volume_24h.append('n/a')
         #market_cap
    try:
        market_cap.append(result.find('td',{'class':'td-market_cap cap col-market cap-price text-right'}).get_text().strip())
    except:    
        market_cap.append('n/a')

# %% [markdown]
# ## dataframe

# %%
crypto_df=pd.DataFrame({'name':name,'price':price,'1h_change':change_1h,'24_change':change_24h,'7d_change':change_7d,'volume_24h':volume_24h,'market_cap':market_cap})

# %%
crypto_df
# Out:
#             name            price 1h_change 24_change 7d_change  \
# 0        Bitcoin       $20,098.22     -0.4%     -0.8%      4.2%
# 1       Ethereum        $1,588.86     -0.0%     -0.9%     -2.5%
# 2         Tether        $0.999790      0.0%      0.0%     -0.0%
# 3       USD Coin        $0.998824     -0.1%     -0.1%     -0.1%
# 4            BNB          $276.08      0.3%     -1.2%     -1.0%
# ..           ...              ...       ...       ...       ...
# 95           Amp  $0.005707964731     -6.5%      1.8%      2.2%
# 96         Waves            $4.33      0.1%     -2.2%     -2.2%
# 97  Bitcoin Gold           $24.09      0.1%      0.6%      1.0%
# 98   Tether Gold        $1,704.62     -0.2%     -0.1%     -0.3%
# 99     Curve DAO            $1.07      0.0%     -4.8%     -8.7%
#
#          volume_24h        market_cap
# 0   $37,166,371,696  $385,327,115,539
# 1   $23,787,340,718  $191,737,631,601
# 2   $52,597,518,343   $67,882,847,791
# 3    $7,290,874,600   $50,745,506,082
# 4      $833,874,601   $45,051,165,950
# ..              ...               ...
# 95      $12,395,017      $439,539,954
# 96      $88,322,323      $433,128,118
# 97      $11,435,116      $423,136,558
# 98       $2,456,908      $420,982,395
# 99     $123,646,074      $417,881,642
#
# [100 rows x 7 columns]

# %% [markdown]
# ## to excel

# %%
crypto_df.to_excel('crypto_data.xlsx',index=False)

# %% [markdown]
# # part2 pagination

# %%
name = []
price = []
change_1h = []
change_24h = []
change_7d = []
volume_24h = []
market_cap = []

for i in range(1,11):
    website="https://www.coingecko.com/?page="+ str(i)
    
    #request
    response= requests.get(website)
    
    #soup
    soup= BeautifulSoup(response.content, 'html.parser')
    
    #results
    results = soup.find('table',{'class':'sort table mb-0 text-sm text-lg-normal table-scrollable'}).find('tbody').find_all('tr')
    
    for result in results:
    
            #name
        try:
            name.append(result.find('span',{'class':'lg:tw-flex font-bold tw-items-center tw-justify-between'}).get_text().strip())
        except:
            name.append('n/a')
            #price
        try:
            price.append(result.find('td',{'class':'td-price price text-right'}).get_text().strip())
        except:
            price.append('n/a')
            #1h_change
        try:
            change_1h.append(result.find('td',{'class':'td-change1h change1h stat-percent text-right col-market'}).get_text().strip())
        except:
            change_1h.append('n/a')
            #24h_change
        try:
            change_24h.append(result.find('td',{'class':'td-change24h'}).get_text().strip())
        except:
            change_24h.append('n/a')
            #7d_change
        try:
            change_7d.append(result.find('td',{'class':'td-change7d'}).get_text().strip())
        except:
            change_7d.append('n/a')
            #volume_24h
        try:
            volume_24h.append(result.find('td',{'class':'td-liquidity_score'}).get_text().strip())
        except:
            volume_24h.append('n/a')
            #market_cap
        try:
            market_cap.append(result.find('td',{'class':'td-market_cap cap col-market cap-price text-right'}).get_text().strip())
        except:    
            market_cap.append('n/a')

# %%
crypto_df_multiple_pages=pd.DataFrame({'name':name,'price':price,'1h_change':change_1h,'24_change':change_24h,'7d_change':change_7d,'volume_24h':volume_24h,'market_cap':market_cap})

# %%
crypto_df_multiple_pages
# Out:
#                    name            price 1h_change 24_change 7d_change  \
# 0               Bitcoin       $20,088.99     -0.4%     -0.8%      4.2%
# 1              Ethereum        $1,586.92     -0.2%     -1.0%     -2.6%
# 2                Tether        $0.999790      0.0%      0.0%     -0.0%
# 3              USD Coin        $0.997883     -0.2%     -0.2%     -0.2%
# 4                   BNB          $275.74      0.2%     -1.3%     -1.1%
# ..                  ...              ...       ...       ...       ...
# 995  Project SEED SHILL  $0.027222560076     -3.1%      6.9%     15.8%
# 996          BreederDAO  $0.096094166026      0.0%     -0.8%     -6.6%
# 997           BoringDAO  $0.007529452888     -0.1%      0.7%    -10.8%
# 998           SideShift  $0.081735757649     -4.1%    -13.7%    -34.7%
# 999               StorX  $0.024428775813     -0.2%      0.7%      0.3%
#
#           volume_24h        market_cap
# 0    $37,161,433,881  $385,327,115,539
# 1    $23,766,390,841  $191,737,631,601
# 2    $52,597,518,343   $67,882,847,791
# 3     $7,281,651,936   $50,745,506,082
# 4       $706,330,558   $45,051,165,950
# ..               ...               ...
# 995         $931,902        $7,647,218
# 996         $114,025        $7,638,267
# 997         $411,349        $7,626,599
# 998       $22,549.54        $7,610,581
# 999         $186,693        $7,601,771
#
# [1000 rows x 7 columns]

# %%
crypto_df.to_excel('crypto_data_multiple_pages.xlsx',index=False)
